# %%
import bcrypt

password = "admin123".encode("utf-8")
hash = bcrypt.hashpw(password, bcrypt.gensalt())
print(hash)
# Out:
# b'$2b$12$T2H/aELDQ.TQyZVoHF0Poetee8gwnuXix3uf8TW55aHlYgDTCpqHC'

# %%
import bcrypt

print(bcrypt.hashpw("admin123".encode(), bcrypt.gensalt()).decode())
# Out:
# $2b$12$RsZOWvM2SS1kNPSqhz/.Y.aK9OFch07tGEhxp6HIjZxpSawKvEXZO
